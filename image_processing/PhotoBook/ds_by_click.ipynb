# %%
# %load_ext autoreload
# %autoreload 2
from logsProcessing_export import display_round_stripe, round_list_tpl, Log
# Out:
# Loading logs from logs...
# 2504 files found.
# DONE. Loaded 2504 completed game logs.

# %%
len(round_list_tpl)
# Out:
# 9626

# %%
def create_click_DS(input_ds):
    counter = 5
    dict_clic_tpls = {}
    for round_tuple in input_ds:
        if counter > 0:
            round_data = round_tuple[0]
            game_id = round_tuple[1]

            round_name = "{}_{}".format(game_id, round_data.round_nr)
            
            dial_string = ""
            click_counter = 0
            
            for message in round_data.messages:
                if message.type == "text":
                    dial_string += "{}: {}\n".format(message.speaker, message.text)
        
                if message.type == "selection":
                    click_counter += 1
                    label = "common" if message.text.split()[1] == "<com>" else "different"
                    marking_act = "{} marks image {} as {}\n".format(message.speaker, Log.strip_image_id(message.text.split()[2]), label)
                    # {Game_Round_Click : [0:dial_string, 1:marking_act, 2:marking_player, 3:marked_image_number, 4:marked_label, 5:Dictionary of images {player:[img_path]}]}

                    dict_clic_tpls[round_name + "_" + str(click_counter)] = (dial_string, marking_act, message.speaker, Log.strip_image_id(message.text.split()[2]), label, round_data.images)
                    dial_string += marking_act

            counter -= 1
    return dict_clic_tpls
click_DS = create_click_DS(round_list_tpl)

# %%
click_DS
# Out:
# {'1048_2_1': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\n",
#   'A marks image 161846 as different\n',
#   'A',
#   161846,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_2': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\n",
#   'A marks image 161846 as common\n',
#   'A',
#   161846,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_3': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\nA marks image 161846 as common\n",
#   'A marks image 244425 as common\n',
#   'A',
#   244425,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_4': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\nA marks image 161846 as common\nA marks image 244425 as common\nB: Yes\n",
#   'B marks image 244425 as common\n',
#   'B',
#   244425,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_5': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\nA marks image 161846 as common\nA marks image 244425 as common\nB: Yes\nB marks image 244425 as common\n",
#   'B marks image 161846 as common\n',
#   'B',
#   161846,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_6': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\nA marks image 161846 as common\nA marks image 244425 as common\nB: Yes\nB marks image 244425 as common\nB marks image 161846 as common\nA: I have one that looks like two plates of chinese food and a small bowl at the top, all on\nA: white/blue plates\nB: okay i have one with a square container with 4 sections one with veggies, a sandwich, fruit and som\nA: Don't have yours\n",
#   'B marks image 260248 as different\n',
#   'B',
#   260248,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_2_7': ("A: I've got three blue bowls, the one on the left has carrots and celery\nB: I have a picture of square pizza in a dish next to a salad.\nB: I don't have that one.\nB: wait\nA: Is the salad on the right in a clear bowl?\nA marks image 161846 as different\nB: i have that one i think with the carrots and celery, the other bowl has blood oranges in it\nB: and yes the salad is in a clear bowl in the other one\nA: Ok, we have both of those then\nA marks image 161846 as common\nA marks image 244425 as common\nB: Yes\nB marks image 244425 as common\nB marks image 161846 as common\nA: I have one that looks like two plates of chinese food and a small bowl at the top, all on\nA: white/blue plates\nB: okay i have one with a square container with 4 sections one with veggies, a sandwich, fruit and som\nA: Don't have yours\nB marks image 260248 as different\nB: okay i dont have that chinese food one \nA: Ok\n",
#   'A marks image 310714 as different\n',
#   'A',
#   310714,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg']}),
#  '1048_3_1': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\n",
#   'B marks image 132002 as common\n',
#   'B',
#   132002,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_3_2': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\nB marks image 132002 as common\n",
#   'A marks image 132002 as common\n',
#   'A',
#   132002,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_3_3': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\nB marks image 132002 as common\nA marks image 132002 as common\nA: I've got those two plates of chinese food and the bowl at the top again\nB: are the plates pink?\nA: no, they are white\nA: one has blue around the edge\nB: I dont have that one\n",
#   'A marks image 310714 as different\n',
#   'A',
#   310714,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_3_4': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\nB marks image 132002 as common\nA marks image 132002 as common\nA: I've got those two plates of chinese food and the bowl at the top again\nB: are the plates pink?\nA: no, they are white\nA: one has blue around the edge\nB: I dont have that one\nA marks image 310714 as different\nA: I also have one that has two plates containing noodles and vegetables and there are beers at the to\nB: I have one with an oval-ish white container with 3 sections next to a metal thing with rice\nB: i have that one\n",
#   'A marks image 356290 as common\n',
#   'A',
#   356290,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_3_5': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\nB marks image 132002 as common\nA marks image 132002 as common\nA: I've got those two plates of chinese food and the bowl at the top again\nB: are the plates pink?\nA: no, they are white\nA: one has blue around the edge\nB: I dont have that one\nA marks image 310714 as different\nA: I also have one that has two plates containing noodles and vegetables and there are beers at the to\nB: I have one with an oval-ish white container with 3 sections next to a metal thing with rice\nB: i have that one\nA marks image 356290 as common\nA: I don't have yours\n",
#   'B marks image 144797 as different\n',
#   'B',
#   144797,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_3_6': ("A: I've got what looks like a cat and a tree with pink rice\nB: yes I have that one\nB marks image 132002 as common\nA marks image 132002 as common\nA: I've got those two plates of chinese food and the bowl at the top again\nB: are the plates pink?\nA: no, they are white\nA: one has blue around the edge\nB: I dont have that one\nA marks image 310714 as different\nA: I also have one that has two plates containing noodles and vegetables and there are beers at the to\nB: I have one with an oval-ish white container with 3 sections next to a metal thing with rice\nB: i have that one\nA marks image 356290 as common\nA: I don't have yours\nB marks image 144797 as different\n",
#   'B marks image 356290 as common\n',
#   'B',
#   356290,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg']}),
#  '1048_4_1': ('A: have celery and carrots again\nB: same with the blood orange i have it\n',
#   'B marks image 161846 as common\n',
#   'B',
#   161846,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_4_2': ('A: have celery and carrots again\nB: same with the blood orange i have it\nB marks image 161846 as common\n',
#   'A marks image 161846 as common\n',
#   'A',
#   161846,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_4_3': ("A: have celery and carrots again\nB: same with the blood orange i have it\nB marks image 161846 as common\nA marks image 161846 as common\nB: i have the noodles dish and 2 beers on top again\nA: don't have that one\n",
#   'B marks image 356290 as different\n',
#   'B',
#   356290,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_4_4': ("A: have celery and carrots again\nB: same with the blood orange i have it\nB marks image 161846 as common\nA marks image 161846 as common\nB: i have the noodles dish and 2 beers on top again\nA: don't have that one\nB marks image 356290 as different\nA: i've got the sandwich with the oranges to the right\nB: dont have that one\n",
#   'A marks image 260248 as different\n',
#   'A',
#   260248,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_4_5': ("A: have celery and carrots again\nB: same with the blood orange i have it\nB marks image 161846 as common\nA marks image 161846 as common\nB: i have the noodles dish and 2 beers on top again\nA: don't have that one\nB marks image 356290 as different\nA: i've got the sandwich with the oranges to the right\nB: dont have that one\nA marks image 260248 as different\nA: i've got those two plates of chinese food yet again with the bowl at the top\nB: i have the 2 dishes of chinese food with the bowl on top and the blue circle mat\nB: yes\n",
#   'A marks image 310714 as common\n',
#   'A',
#   310714,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_4_6': ("A: have celery and carrots again\nB: same with the blood orange i have it\nB marks image 161846 as common\nA marks image 161846 as common\nB: i have the noodles dish and 2 beers on top again\nA: don't have that one\nB marks image 356290 as different\nA: i've got the sandwich with the oranges to the right\nB: dont have that one\nA marks image 260248 as different\nA: i've got those two plates of chinese food yet again with the bowl at the top\nB: i have the 2 dishes of chinese food with the bowl on top and the blue circle mat\nB: yes\nA marks image 310714 as common\n",
#   'B marks image 310714 as common\n',
#   'B',
#   310714,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000395097.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg']}),
#  '1048_5_1': ('A: have the plates with beers\nB: dont have that one this time\n',
#   'A marks image 356290 as different\n',
#   'A',
#   356290,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_5_2': ("A: have the plates with beers\nB: dont have that one this time\nA marks image 356290 as different\nB: i have the cat one with pink rice\nA: have the pizza and salad\nA: don't have the cat\nB: i have the pizza and salad one\nA: ok\n",
#   'A marks image 244425 as common\n',
#   'A',
#   244425,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_5_3': ("A: have the plates with beers\nB: dont have that one this time\nA marks image 356290 as different\nB: i have the cat one with pink rice\nA: have the pizza and salad\nA: don't have the cat\nB: i have the pizza and salad one\nA: ok\nA marks image 244425 as common\n",
#   'B marks image 132002 as different\n',
#   'B',
#   132002,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_5_4': ("A: have the plates with beers\nB: dont have that one this time\nA marks image 356290 as different\nB: i have the cat one with pink rice\nA: have the pizza and salad\nA: don't have the cat\nB: i have the pizza and salad one\nA: ok\nA marks image 244425 as common\nB marks image 132002 as different\n",
#   'B marks image 244425 as common\n',
#   'B',
#   244425,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_5_5': ("A: have the plates with beers\nB: dont have that one this time\nA marks image 356290 as different\nB: i have the cat one with pink rice\nA: have the pizza and salad\nA: don't have the cat\nB: i have the pizza and salad one\nA: ok\nA marks image 244425 as common\nB marks image 132002 as different\nB marks image 244425 as common\nA: i have the white tray with three compartments and the rice bowl\nB: i have that one\n",
#   'A marks image 144797 as common\n',
#   'A',
#   144797,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_5_6': ("A: have the plates with beers\nB: dont have that one this time\nA marks image 356290 as different\nB: i have the cat one with pink rice\nA: have the pizza and salad\nA: don't have the cat\nB: i have the pizza and salad one\nA: ok\nA marks image 244425 as common\nB marks image 132002 as different\nB marks image 244425 as common\nA: i have the white tray with three compartments and the rice bowl\nB: i have that one\nA marks image 144797 as common\nA: ok, i'm ready\nB: i have the square container with 4 sections one is a sandwich\nA: don't have that one\n",
#   'B marks image 260248 as different\n',
#   'B',
#   260248,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000100022.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000492731.jpg']}),
#  '1048_6_1': ("A: i've got the pizza and salad\nB: I dont have that one\n",
#   'A marks image 244425 as different\n',
#   'A',
#   244425,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']}),
#  '1048_6_2': ("A: i've got the pizza and salad\nB: I dont have that one\nA marks image 244425 as different\nA: i've got the cat and pink rice\nB: i have the cat with the pink rice again\nB: yes\n",
#   'A marks image 132002 as common\n',
#   'A',
#   132002,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']}),
#  '1048_6_3': ("A: i've got the pizza and salad\nB: I dont have that one\nA marks image 244425 as different\nA: i've got the cat and pink rice\nB: i have the cat with the pink rice again\nB: yes\nA marks image 132002 as common\nA: and i've got the sandwich with 4 compartments\nB: okay i have the chinese food with the bowl on top\nA: don't have the chinese food this time\nB: i have that sandwich one \n",
#   'B marks image 310714 as different\n',
#   'B',
#   310714,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']}),
#  '1048_6_4': ("A: i've got the pizza and salad\nB: I dont have that one\nA marks image 244425 as different\nA: i've got the cat and pink rice\nB: i have the cat with the pink rice again\nB: yes\nA marks image 132002 as common\nA: and i've got the sandwich with 4 compartments\nB: okay i have the chinese food with the bowl on top\nA: don't have the chinese food this time\nB: i have that sandwich one \nB marks image 310714 as different\n",
#   'A marks image 260248 as common\n',
#   'A',
#   260248,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']}),
#  '1048_6_5': ("A: i've got the pizza and salad\nB: I dont have that one\nA marks image 244425 as different\nA: i've got the cat and pink rice\nB: i have the cat with the pink rice again\nB: yes\nA marks image 132002 as common\nA: and i've got the sandwich with 4 compartments\nB: okay i have the chinese food with the bowl on top\nA: don't have the chinese food this time\nB: i have that sandwich one \nB marks image 310714 as different\nA marks image 260248 as common\n",
#   'B marks image 260248 as common\n',
#   'B',
#   260248,
#   'common',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']}),
#  '1048_6_6': ("A: i've got the pizza and salad\nB: I dont have that one\nA marks image 244425 as different\nA: i've got the cat and pink rice\nB: i have the cat with the pink rice again\nB: yes\nA marks image 132002 as common\nA: and i've got the sandwich with 4 compartments\nB: okay i have the chinese food with the bowl on top\nA: don't have the chinese food this time\nB: i have that sandwich one \nB marks image 310714 as different\nA marks image 260248 as common\nB marks image 260248 as common\nB: i have the noodles dish with the 2 beers on top again\nA: don't have that one\n",
#   'B marks image 356290 as different\n',
#   'B',
#   356290,
#   'different',
#   {'A': ['bowl_dining_table/COCO_train2014_000000492731.jpg',
#     'bowl_dining_table/COCO_train2014_000000386603.jpg',
#     'bowl_dining_table/COCO_train2014_000000244425.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000086285.jpg'],
#    'B': ['bowl_dining_table/COCO_train2014_000000356290.jpg',
#     'bowl_dining_table/COCO_train2014_000000260248.jpg',
#     'bowl_dining_table/COCO_train2014_000000310714.jpg',
#     'bowl_dining_table/COCO_train2014_000000144797.jpg',
#     'bowl_dining_table/COCO_train2014_000000132002.jpg',
#     'bowl_dining_table/COCO_train2014_000000161846.jpg']})}
