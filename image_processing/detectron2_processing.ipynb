# %%
# Code in this notebook is based on tutorial notebook from Detectron2
# Yuxin Wu, Alexander Kirillov, Francisco Massa, Wan-Yen Lo, & Ross Girshick. (2019). Detectron2. .

# %%
# CUDA_VISIBLE_DEVICES=""

# %%
import sys, os, distutils.core
import torch, detectron2
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt 
import json
import matplotlib.image as mpimg

# from google.colab.patches import cv2_imshow

from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# /bin/bash: line 1: nvcc: command not found
# torch:  2.4 ; cuda:  cu121
# detectron2: 0.6

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
im = cv2.imread("./input.jpg")
im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

plt.imshow(im_rgb)
plt.axis("off")
plt.show()

# %%
cfg = get_cfg()
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [03/27 12:48:47 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# /home/gusloryst@GU.GU.SE/d2env/lib/python3.8/site-packages/torch/functional.py:513: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3609.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# dir(outputs["instances"])
outputs["instances"]._fields.keys()
# Out:
# dict_keys(['pred_boxes', 'scores', 'pred_classes', 'pred_masks'])

# %%
# look at the outputs. See https://detectron2.readthedocs.io/tutorials/models.html#model-output-format for specification
print(outputs["instances"].pred_classes)
# Out:
# tensor([17,  0,  0,  0,  0,  0,  0,  0, 25,  0, 25, 25,  0,  0, 24],
#        device='cuda:0')

# %%
classes = MetadataCatalog.get(cfg.DATASETS.TRAIN[0]).thing_classes
for clss in outputs["instances"].pred_classes:
    print(classes[clss.item()])
# Out:
# horse
# person
# person
# person
# person
# person
# person
# person
# umbrella
# person
# umbrella
# umbrella
# person
# person
# backpack

# %%
# We can use `Visualizer` to draw the predictions on the image.
v = Visualizer(im_rgb[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

outed = out.get_image()
out_rgb = cv2.cvtColor(outed, cv2.COLOR_BGR2RGB)


plt.imshow(out_rgb)
plt.axis("off")
plt.show()

# %%
path1 = "./PhotoBook/images/cake_dining_table/COCO_train2014_000000126144.jpg"
path2 = "./PhotoBook/images/cake_dining_table/COCO_train2014_000000134238.jpg"
path3 = "./PhotoBook/images/cake_dining_table/COCO_train2014_000000134599.jpg"
path4 = "./PhotoBook/images/cake_dining_table/COCO_train2014_000000152914.jpg"

example = cv2.imread(path2)
xmpl_rgb = cv2.cvtColor(example, cv2.COLOR_BGR2RGB)

plt.imshow(xmpl_rgb)
plt.axis("off")
plt.show()

# %%
exmpl_outputs = predictor(example)
print(exmpl_outputs["instances"].pred_classes)
print(exmpl_outputs["instances"].pred_boxes)
# Out:
# tensor([46, 45, 45, 60, 49, 49, 48, 51, 51], device='cuda:0')
# Boxes(tensor([[1.6213e+02, 4.6604e+01, 3.6151e+02, 2.0901e+02],
#         [3.5277e+02, 1.0648e+02, 5.8278e+02, 2.0181e+02],
#         [0.0000e+00, 3.1134e+00, 2.2304e+02, 2.0560e+02],
#         [0.0000e+00, 4.3980e+01, 6.3091e+02, 4.6904e+02],
#         [1.0610e+00, 4.9907e+00, 9.5677e+01, 7.9085e+01],
#         [8.9783e+01, 4.9006e-01, 2.0903e+02, 6.7071e+01],
#         [1.7741e+02, 1.7008e+02, 5.3228e+02, 4.3078e+02],
#         [2.7036e+02, 2.6861e+02, 3.4250e+02, 3.3326e+02],
#         [2.6867e+02, 3.2917e+02, 3.4668e+02, 3.7400e+02]], device='cuda:0'))

# %%
print(exmpl_outputs["instances"]._fields.keys())
# Out:
# dict_keys(['pred_boxes', 'scores', 'pred_classes', 'pred_masks'])

# %%
v2 = Visualizer(xmpl_rgb[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
xmpl_out = v2.draw_instance_predictions(exmpl_outputs["instances"].to("cpu"))
xmpl_outed = xmpl_out.get_image()
xmpl_out_rgb = cv2.cvtColor(xmpl_outed, cv2.COLOR_BGR2RGB)
plt.imshow(xmpl_out_rgb)
plt.axis("off")
# Out:
# (-0.5, 767.5, 575.5, -0.5)

# %%
# the code below is taken from my file called readData in Photobook folder

# %%
with open('PhotoBook/v2/gold-extracted.json', 'r') as file:
    data = json.load(file)
    img_description = {}
    # print(data["person_truck/COCO_train2014_000000258505.jpg"])
    for key in data.keys():
        list_utterances = []
        for subkey in data[key]:
            for dictionary_object in data[key][subkey]:
                list_utterances.append(dictionary_object["Message_Text"])
        img_description[key] = list_utterances

# %%
def show_img_descriptions(title, main_dict):
    list_of_keys = list(main_dict.keys())
    if isinstance(title, int):
        title = list_of_keys[title]
    for i, descr in enumerate(main_dict[title]):
        print(i, "-", descr)

    image = mpimg.imread("PhotoBook/images/" + title)
    plt.imshow(image)

# show_img_descriptions(50, img_description)

# %%
def compare_dial_Detectron2(title, main_dict):
    list_of_keys = list(main_dict.keys())
    if isinstance(title, int):
        title = list_of_keys[title]
    for i, descr in enumerate(main_dict[title]):
        print(i, "-", descr)

    photo = mpimg.imread("PhotoBook/images/" + title)
    outcome = predictor(photo)

    # predicted_classes = outcome["instances"].pred_classes
    # bounding_boxes = outcome["instances"].pred_boxes
    v3 = Visualizer(photo[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)

    drawn = v3.draw_instance_predictions(outcome["instances"].to("cpu"))

    visualised = drawn.get_image()
    # out_rgb = cv2.cvtColor(outed, cv2.COLOR_BGR2RGB)
    
    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[1].imshow(photo)
    axes[1].axis('off')

    axes[0].imshow(visualised)
    axes[0].axis('off')
    plt.tight_layout()
    plt.show()

    # plt.imshow(photo)
    # plt.imshow(visualised)

# %%
compare_dial_Detectron2(100, img_description)
# Out:
# 0 - I have three people standing in front of a open cabinet of bread or other food talking
# 1 - I don't have her this time
# 2 - The tattoed guy with the cabinet of fruit and two other people I have

# %%
# Relation detection:
# Tang, K.. (2020). A Scene Graph Generation Codebase in PyTorch.
# Tang, K., Zhang, H., Wu, B., Luo, W., & Liu, W. (2019). Learning to Compose Dynamic Tree Structures for Visual Contexts. In Conference on Computer Vision and Pattern Recognition.
# Tang, K., Niu, Y., Huang, J., Shi, J., & Zhang, H. (2020). Unbiased Scene Graph Generation from Biased Training. In Conference on Computer Vision and Pattern Recognition.

#

# %%
classes = MetadataCatalog.get(cfg.DATASETS.TRAIN[0]).thing_classes

with open('PhotoBook/v2/gold-extracted.json', 'r') as file:
    data = json.load(file)
    file2detected_objects = {}
    for key in data.keys():
        photo = mpimg.imread("PhotoBook/images/" + key)
        outcome = predictor(photo)
        encoded_classes = outcome["instances"].pred_classes
        decoded_classes = [classes[clss.item()] for clss in encoded_classes]
        file2detected_objects[key] = decoded_classes

# %%
len(file2detected_objects)
# Out:
# 208

# %%
# %store file2detected_objects
# Out:
# Stored 'file2detected_objects' (dict)

# %%
file2detected_objects
# Out:
# {'person_truck/COCO_train2014_000000258505.jpg': ['person',
#   'person',
#   'person',
#   'sports ball',
#   'sports ball',
#   'car',
#   'chair',
#   'person',
#   'bottle',
#   'baseball bat',
#   'car',
#   'truck'],
#  'person_truck/COCO_train2014_000000418229.jpg': ['person',
#   'truck',
#   'car',
#   'bottle',
#   'fire hydrant',
#   'person'],
#  'person_truck/COCO_train2014_000000237372.jpg': ['person',
#   'umbrella',
#   'car',
#   'car',
#   'car',
#   'car'],
#  'person_truck/COCO_train2014_000000227003.jpg': ['person',
#   'person',
#   'stop sign',
#   'truck',
#   'backpack'],
#  'person_truck/COCO_train2014_000000035995.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'tie',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'tie',
#   'person',
#   'truck'],
#  'person_truck/COCO_train2014_000000099245.jpg': ['person',
#   'sports ball',
#   'car',
#   'car',
#   'sports ball',
#   'truck',
#   'car',
#   'handbag',
#   'suitcase',
#   'sports ball',
#   'car'],
#  'person_truck/COCO_train2014_000000185945.jpg': ['person', 'sports ball'],
#  'person_truck/COCO_train2014_000000190016.jpg': ['person',
#   'person',
#   'truck',
#   'person',
#   'truck',
#   'handbag',
#   'backpack',
#   'bus',
#   'cup',
#   'truck'],
#  'person_surfboard/COCO_train2014_000000111385.jpg': ['person',
#   'person',
#   'person',
#   'surfboard',
#   'surfboard'],
#  'person_surfboard/COCO_train2014_000000340331.jpg': ['surfboard',
#   'person',
#   'person',
#   'snowboard',
#   'surfboard'],
#  'person_surfboard/COCO_train2014_000000374388.jpg': ['person', 'surfboard'],
#  'person_surfboard/COCO_train2014_000000572061.jpg': ['person',
#   'person',
#   'person',
#   'person'],
#  'person_surfboard/COCO_train2014_000000314741.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'surfboard',
#   'person',
#   'person',
#   'person',
#   'person',
#   'surfboard',
#   'person',
#   'person'],
#  'person_surfboard/COCO_train2014_000000079720.jpg': ['person',
#   'person',
#   'surfboard',
#   'person',
#   'person',
#   'person'],
#  'person_surfboard/COCO_train2014_000000387812.jpg': ['person',
#   'surfboard',
#   'surfboard',
#   'person',
#   'person'],
#  'person_surfboard/COCO_train2014_000000097094.jpg': ['person',
#   'handbag',
#   'surfboard'],
#  'person_bicycle/COCO_train2014_000000256981.jpg': ['person',
#   'backpack',
#   'bicycle',
#   'potted plant',
#   'bicycle'],
#  'person_bicycle/COCO_train2014_000000086189.jpg': ['bicycle',
#   'person',
#   'car',
#   'person',
#   'person',
#   'car',
#   'truck',
#   'car'],
#  'person_bicycle/COCO_train2014_000000034815.jpg': ['person',
#   'person',
#   'bicycle',
#   'bicycle',
#   'bottle',
#   'train',
#   'handbag',
#   'handbag',
#   'bus',
#   'backpack'],
#  'person_bicycle/COCO_train2014_000000266311.jpg': ['skateboard',
#   'person',
#   'bicycle',
#   'bicycle',
#   'person',
#   'person',
#   'bicycle',
#   'person',
#   'boat',
#   'boat',
#   'boat',
#   'person',
#   'person',
#   'person'],
#  'person_bicycle/COCO_train2014_000000293658.jpg': ['person',
#   'car',
#   'bicycle'],
#  'person_bicycle/COCO_train2014_000000527112.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'bottle',
#   'bicycle',
#   'person',
#   'bottle',
#   'bicycle',
#   'bicycle',
#   'person',
#   'bicycle',
#   'frisbee'],
#  'person_bicycle/COCO_train2014_000000441488.jpg': ['person',
#   'bicycle',
#   'bicycle',
#   'cell phone'],
#  'person_bicycle/COCO_train2014_000000386326.jpg': ['person',
#   'bicycle',
#   'bus',
#   'bus',
#   'person',
#   'person',
#   'bus',
#   'vase'],
#  'car_motorcycle/COCO_train2014_000000144597.jpg': ['person',
#   'car',
#   'car',
#   'car',
#   'motorcycle'],
#  'car_motorcycle/COCO_train2014_000000127400.jpg': ['person',
#   'motorcycle',
#   'car',
#   'backpack',
#   'bottle'],
#  'car_motorcycle/COCO_train2014_000000215201.jpg': ['motorcycle',
#   'person',
#   'car'],
#  'car_motorcycle/COCO_train2014_000000024608.jpg': ['person',
#   'car',
#   'car',
#   'car',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'chair',
#   'person',
#   'handbag',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'car_motorcycle/COCO_train2014_000000293647.jpg': ['car',
#   'person',
#   'motorcycle',
#   'car',
#   'person',
#   'motorcycle',
#   'motorcycle'],
#  'car_motorcycle/COCO_train2014_000000345207.jpg': ['motorcycle',
#   'car',
#   'car',
#   'car'],
#  'car_motorcycle/COCO_train2014_000000256560.jpg': ['motorcycle',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'person'],
#  'car_truck/COCO_train2014_000000075299.jpg': ['person',
#   'person',
#   'car',
#   'car',
#   'car',
#   'umbrella',
#   'truck',
#   'car',
#   'car',
#   'stop sign',
#   'car'],
#  'car_truck/COCO_train2014_000000237372.jpg': ['person',
#   'umbrella',
#   'car',
#   'car',
#   'car',
#   'car'],
#  'car_truck/COCO_train2014_000000339250.jpg': ['car',
#   'truck',
#   'car',
#   'truck',
#   'truck',
#   'airplane',
#   'truck',
#   'person',
#   'person'],
#  'couch_laptop/COCO_train2014_000000174573.jpg': ['laptop',
#   'cat',
#   'potted plant',
#   'keyboard',
#   'potted plant',
#   'couch',
#   'person'],
#  'couch_laptop/COCO_train2014_000000380128.jpg': ['mouse',
#   'laptop',
#   'keyboard'],
#  'couch_laptop/COCO_train2014_000000407139.jpg': ['laptop',
#   'bottle',
#   'cat',
#   'person',
#   'book',
#   'bed'],
#  'couch_laptop/COCO_train2014_000000452004.jpg': ['person',
#   'laptop',
#   'couch',
#   'person',
#   'person',
#   'person',
#   'teddy bear',
#   'couch'],
#  'couch_laptop/COCO_train2014_000000469405.jpg': ['laptop',
#   'remote',
#   'couch',
#   'bed',
#   'person'],
#  'couch_laptop/COCO_train2014_000000233786.jpg': ['cat', 'laptop'],
#  'couch_laptop/COCO_train2014_000000179961.jpg': ['cup',
#   'bowl',
#   'chair',
#   'laptop',
#   'keyboard',
#   'person',
#   'couch',
#   'chair',
#   'couch'],
#  'person_train/COCO_train2014_000000246396.jpg': ['person',
#   'cell phone',
#   'bus',
#   'person',
#   'person'],
#  'person_train/COCO_train2014_000000178018.jpg': ['person', 'train', 'person'],
#  'person_train/COCO_train2014_000000480295.jpg': ['person',
#   'person',
#   'tie',
#   'handbag'],
#  'person_car/COCO_train2014_000000121619.jpg': ['person',
#   'parking meter',
#   'car',
#   'car'],
#  'person_car/COCO_train2014_000000282514.jpg': ['person',
#   'person',
#   'traffic light',
#   'donut',
#   'traffic light',
#   'traffic light',
#   'traffic light',
#   'traffic light',
#   'traffic light',
#   'donut',
#   'traffic light',
#   'traffic light',
#   'car'],
#  'person_car/COCO_train2014_000000011619.jpg': ['person',
#   'car',
#   'car',
#   'car',
#   'person',
#   'cell phone',
#   'chair',
#   'car',
#   'car',
#   'chair'],
#  'person_car/COCO_train2014_000000425647.jpg': ['car',
#   'cell phone',
#   'person',
#   'person',
#   'person',
#   'car',
#   'car',
#   'car',
#   'car'],
#  'person_car/COCO_train2014_000000563545.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'tie',
#   'cell phone',
#   'tie',
#   'car'],
#  'person_car/COCO_train2014_000000394151.jpg': ['person',
#   'suitcase',
#   'suitcase',
#   'chair',
#   'car'],
#  'person_car/COCO_train2014_000000126097.jpg': ['person',
#   'parking meter',
#   'parking meter',
#   'car',
#   'sink',
#   'potted plant'],
#  'person_car/COCO_train2014_000000405991.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'cup',
#   'person',
#   'handbag',
#   'person',
#   'car',
#   'car',
#   'handbag'],
#  'person_elephant/COCO_train2014_000000524059.jpg': ['person',
#   'elephant',
#   'bear',
#   'elephant'],
#  'person_elephant/COCO_train2014_000000337304.jpg': ['person',
#   'elephant',
#   'elephant',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'handbag',
#   'person',
#   'person',
#   'backpack',
#   'bench'],
#  'person_elephant/COCO_train2014_000000033416.jpg': ['person',
#   'person',
#   'elephant',
#   'person',
#   'person',
#   'person',
#   'person',
#   'elephant',
#   'elephant',
#   'umbrella'],
#  'person_elephant/COCO_train2014_000000532644.jpg': ['elephant',
#   'person',
#   'elephant',
#   'person',
#   'person'],
#  'person_elephant/COCO_train2014_000000065220.jpg': ['elephant', 'person'],
#  'person_elephant/COCO_train2014_000000204759.jpg': ['person',
#   'elephant',
#   'person',
#   'handbag',
#   'handbag'],
#  'person_elephant/COCO_train2014_000000095257.jpg': ['person',
#   'elephant',
#   'elephant',
#   'person',
#   'person',
#   'elephant',
#   'person',
#   'bench',
#   'bench'],
#  'person_elephant/COCO_train2014_000000571351.jpg': ['person',
#   'elephant',
#   'person',
#   'elephant',
#   'person',
#   'person',
#   'elephant',
#   'person'],
#  'person_train/COCO_train2014_000000313709.jpg': ['person',
#   'person',
#   'handbag',
#   'person',
#   'person',
#   'train',
#   'person',
#   'person',
#   'handbag',
#   'person'],
#  'person_train/COCO_train2014_000000382203.jpg': ['person',
#   'train',
#   'backpack',
#   'person',
#   'cell phone'],
#  'person_train/COCO_train2014_000000525163.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'handbag',
#   'train',
#   'person'],
#  'person_train/COCO_train2014_000000085179.jpg': ['person',
#   'person',
#   'backpack',
#   'person',
#   'person',
#   'suitcase',
#   'backpack',
#   'backpack',
#   'train',
#   'suitcase'],
#  'person_car/COCO_train2014_000000258505.jpg': ['person',
#   'person',
#   'person',
#   'sports ball',
#   'sports ball',
#   'car',
#   'chair',
#   'person',
#   'bottle',
#   'baseball bat',
#   'car',
#   'truck'],
#  'person_car/COCO_train2014_000000440460.jpg': ['person',
#   'frisbee',
#   'car',
#   'car',
#   'person',
#   'car',
#   'person',
#   'car',
#   'car',
#   'handbag',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'handbag',
#   'car',
#   'truck',
#   'car',
#   'car',
#   'car',
#   'car'],
#  'person_car/COCO_train2014_000000461187.jpg': ['person', 'bench', 'bench'],
#  'person_car/COCO_train2014_000000195449.jpg': ['person',
#   'dog',
#   'motorcycle',
#   'handbag',
#   'car',
#   'car',
#   'truck'],
#  'couch_dining_table/COCO_train2014_000000509555.jpg': ['bottle',
#   'bottle',
#   'person',
#   'cup',
#   'cup',
#   'cup',
#   'cell phone',
#   'dining table',
#   'bottle',
#   'couch',
#   'bottle'],
#  'couch_dining_table/COCO_train2014_000000010877.jpg': ['chair',
#   'person',
#   'person',
#   'dining table',
#   'cup',
#   'chair',
#   'couch',
#   'person',
#   'couch'],
#  'couch_dining_table/COCO_train2014_000000249727.jpg': ['person',
#   'person',
#   'donut',
#   'donut',
#   'dining table',
#   'knife',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'couch_dining_table/COCO_train2014_000000560969.jpg': ['person',
#   'dining table',
#   'couch',
#   'chair',
#   'chair',
#   'chair',
#   'chair',
#   'chair',
#   'person'],
#  'couch_dining_table/COCO_train2014_000000180606.jpg': ['cup',
#   'person',
#   'knife',
#   'dining table',
#   'chair',
#   'cup',
#   'cup',
#   'bottle',
#   'bottle'],
#  'couch_dining_table/COCO_train2014_000000109895.jpg': ['person',
#   'cake',
#   'person',
#   'dining table',
#   'backpack',
#   'cup',
#   'cup',
#   'knife',
#   'chair',
#   'chair',
#   'cup',
#   'couch',
#   'potted plant',
#   'book',
#   'cup',
#   'car'],
#  'couch_dining_table/COCO_train2014_000000275014.jpg': ['person',
#   'wine glass',
#   'person',
#   'wine glass',
#   'wine glass',
#   'dining table',
#   'cup',
#   'tie',
#   'cup',
#   'cup',
#   'dining table',
#   'wine glass',
#   'wine glass',
#   'wine glass'],
#  'couch_dining_table/COCO_train2014_000000330652.jpg': ['cup',
#   'cup',
#   'person',
#   'cup',
#   'person',
#   'dining table',
#   'dining table',
#   'person',
#   'spoon',
#   'chair',
#   'book',
#   'cup',
#   'chair'],
#  'person_motorcycle/COCO_train2014_000000560615.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'motorcycle',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'handbag',
#   'person',
#   'person',
#   'motorcycle',
#   'person',
#   'person',
#   'motorcycle',
#   'motorcycle',
#   'person',
#   'cell phone',
#   'motorcycle'],
#  'person_motorcycle/COCO_train2014_000000279373.jpg': ['person',
#   'car',
#   'car',
#   'motorcycle',
#   'car',
#   'car',
#   'motorcycle',
#   'car',
#   'car',
#   'handbag',
#   'car',
#   'motorcycle'],
#  'person_motorcycle/COCO_train2014_000000212969.jpg': ['person',
#   'motorcycle',
#   'backpack',
#   'handbag'],
#  'person_motorcycle/COCO_train2014_000000198072.jpg': ['motorcycle',
#   'motorcycle',
#   'motorcycle',
#   'motorcycle',
#   'person',
#   'person'],
#  'person_motorcycle/COCO_train2014_000000324228.jpg': ['person',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'car',
#   'person',
#   'person',
#   'person',
#   'backpack',
#   'backpack',
#   'person',
#   'person',
#   'person',
#   'person',
#   'handbag',
#   'person',
#   'person'],
#  'person_motorcycle/COCO_train2014_000000238178.jpg': ['person',
#   'person',
#   'motorcycle',
#   'motorcycle',
#   'motorcycle',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'backpack',
#   'person',
#   'person',
#   'person'],
#  'person_motorcycle/COCO_train2014_000000168627.jpg': ['person',
#   'person',
#   'motorcycle',
#   'person',
#   'person',
#   'motorcycle',
#   'person',
#   'person'],
#  'person_motorcycle/COCO_train2014_000000039100.jpg': ['person',
#   'motorcycle',
#   'person',
#   'person',
#   'chair',
#   'person',
#   'person',
#   'person',
#   'chair',
#   'person',
#   'potted plant',
#   'chair'],
#  'car_truck/COCO_train2014_000000056549.jpg': ['chair',
#   'person',
#   'car',
#   'car',
#   'truck',
#   'car',
#   'chair',
#   'car',
#   'person',
#   'car'],
#  'car_truck/COCO_train2014_000000115639.jpg': ['person',
#   'truck',
#   'truck',
#   'person',
#   'person',
#   'person'],
#  'car_truck/COCO_train2014_000000379766.jpg': ['car',
#   'truck',
#   'car',
#   'car',
#   'car',
#   'car',
#   'traffic light',
#   'car',
#   'car',
#   'car',
#   'traffic light',
#   'bus',
#   'car',
#   'car',
#   'car',
#   'car',
#   'traffic light',
#   'car',
#   'car',
#   'traffic light',
#   'car',
#   'car'],
#  'car_truck/COCO_train2014_000000565975.jpg': ['suitcase',
#   'suitcase',
#   'person',
#   'person',
#   'suitcase',
#   'person',
#   'person',
#   'suitcase',
#   'suitcase',
#   'suitcase',
#   'suitcase',
#   'handbag',
#   'handbag',
#   'suitcase',
#   'person',
#   'person',
#   'suitcase',
#   'suitcase',
#   'person',
#   'person',
#   'person',
#   'truck',
#   'suitcase',
#   'person',
#   'suitcase',
#   'person',
#   'person'],
#  'car_truck/COCO_train2014_000000151371.jpg': ['car',
#   'truck',
#   'car',
#   'bus',
#   'person',
#   'parking meter',
#   'potted plant'],
#  'bowl_dining_table/COCO_train2014_000000144797.jpg': ['bowl',
#   'bowl',
#   'dining table',
#   'bowl',
#   'spoon',
#   'cake'],
#  'bowl_dining_table/COCO_train2014_000000161846.jpg': ['bowl',
#   'bowl',
#   'bowl',
#   'dining table'],
#  'bowl_dining_table/COCO_train2014_000000132002.jpg': ['bowl',
#   'broccoli',
#   'broccoli',
#   'cake',
#   'cat',
#   'knife'],
#  'person_surfboard/COCO_train2014_000000515743.jpg': ['bicycle',
#   'person',
#   'cell phone',
#   'surfboard',
#   'boat'],
#  'person_surfboard/COCO_train2014_000000287084.jpg': ['person',
#   'person',
#   'surfboard',
#   'person',
#   'person',
#   'person'],
#  'person_surfboard/COCO_train2014_000000083580.jpg': ['surfboard',
#   'person',
#   'bicycle',
#   'person'],
#  'person_surfboard/COCO_train2014_000000204735.jpg': ['person', 'bed'],
#  'person_refrigerator/COCO_train2014_000000005373.jpg': ['person',
#   'bottle',
#   'refrigerator',
#   'sink',
#   'bottle'],
#  'person_refrigerator/COCO_train2014_000000459209.jpg': ['person',
#   'person',
#   'person',
#   'person'],
#  'person_refrigerator/COCO_train2014_000000305451.jpg': ['person',
#   'person',
#   'cup',
#   'chair',
#   'dining table',
#   'refrigerator',
#   'cake',
#   'book'],
#  'person_refrigerator/COCO_train2014_000000324732.jpg': ['person',
#   'refrigerator',
#   'refrigerator',
#   'refrigerator',
#   'bowl',
#   'bowl',
#   'bottle',
#   'refrigerator',
#   'refrigerator',
#   'bowl',
#   'refrigerator'],
#  'person_refrigerator/COCO_train2014_000000040338.jpg': ['person',
#   'person',
#   'person',
#   'fork',
#   'refrigerator',
#   'person',
#   'bottle',
#   'refrigerator'],
#  'person_refrigerator/COCO_train2014_000000418620.jpg': ['person',
#   'refrigerator',
#   'bottle',
#   'bottle',
#   'cup'],
#  'person_refrigerator/COCO_train2014_000000497591.jpg': ['person',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'refrigerator',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle'],
#  'cake_dining_table/COCO_train2014_000000381996.jpg': ['person', 'person'],
#  'cake_dining_table/COCO_train2014_000000501718.jpg': ['spoon',
#   'cup',
#   'dining table',
#   'cake',
#   'cup',
#   'fork',
#   'bowl',
#   'spoon',
#   'bowl',
#   'bowl',
#   'bowl',
#   'knife'],
#  'cake_dining_table/COCO_train2014_000000126144.jpg': ['person',
#   'person',
#   'cake',
#   'person',
#   'tie'],
#  'person_teddy_bear/COCO_train2014_000000184930.jpg': ['person',
#   'car',
#   'teddy bear',
#   'car',
#   'car',
#   'teddy bear',
#   'person'],
#  'person_teddy_bear/COCO_train2014_000000340923.jpg': ['person',
#   'teddy bear',
#   'couch',
#   'bed'],
#  'person_teddy_bear/COCO_train2014_000000136701.jpg': ['teddy bear',
#   'person',
#   'handbag',
#   'book',
#   'book'],
#  'person_teddy_bear/COCO_train2014_000000157714.jpg': ['teddy bear',
#   'teddy bear',
#   'person',
#   'bed'],
#  'person_teddy_bear/COCO_train2014_000000319818.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'toothbrush',
#   'person',
#   'teddy bear',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'person_teddy_bear/COCO_train2014_000000374391.jpg': ['bottle',
#   'teddy bear',
#   'teddy bear',
#   'bed',
#   'person'],
#  'person_teddy_bear/COCO_train2014_000000419186.jpg': ['person',
#   'person',
#   'person',
#   'person'],
#  'person_teddy_bear/COCO_train2014_000000207354.jpg': ['person',
#   'teddy bear',
#   'chair',
#   'tie'],
#  'car_motorcycle/COCO_train2014_000000514839.jpg': ['person',
#   'person',
#   'person',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'motorcycle',
#   'person',
#   'person',
#   'person',
#   'person',
#   'car',
#   'car',
#   'person',
#   'person',
#   'car',
#   'car',
#   'person',
#   'person',
#   'person',
#   'car',
#   'person'],
#  'car_motorcycle/COCO_train2014_000000494833.jpg': ['motorcycle',
#   'car',
#   'car',
#   'person',
#   'person',
#   'person',
#   'truck',
#   'car',
#   'car'],
#  'car_motorcycle/COCO_train2014_000000477807.jpg': ['person',
#   'person',
#   'person',
#   'motorcycle',
#   'dog',
#   'dog',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'bottle',
#   'motorcycle',
#   'motorcycle',
#   'person',
#   'person',
#   'cell phone',
#   'chair',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'motorcycle',
#   'person'],
#  'car_motorcycle/COCO_train2014_000000054286.jpg': ['person',
#   'motorcycle',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'car',
#   'truck',
#   'car',
#   'person',
#   'truck'],
#  'car_motorcycle/COCO_train2014_000000480807.jpg': ['motorcycle',
#   'cup',
#   'car'],
#  'dining_table_refrigerator/COCO_train2014_000000311337.jpg': ['refrigerator',
#   'sink',
#   'chair',
#   'cup',
#   'sink',
#   'sink',
#   'chair',
#   'refrigerator',
#   'cup',
#   'cup',
#   'book',
#   'cup',
#   'dining table',
#   'cup',
#   'toothbrush',
#   'dining table'],
#  'dining_table_refrigerator/COCO_train2014_000000075726.jpg': ['person',
#   'person',
#   'dining table',
#   'refrigerator',
#   'person',
#   'bowl',
#   'handbag'],
#  'dining_table_refrigerator/COCO_train2014_000000303703.jpg': ['bowl',
#   'bottle',
#   'vase',
#   'bottle',
#   'bottle',
#   'oven',
#   'bottle',
#   'refrigerator',
#   'bottle',
#   'cup',
#   'bottle',
#   'bottle',
#   'cup',
#   'bottle',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'bottle',
#   'bowl',
#   'cup',
#   'potted plant',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'dining table',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'bottle',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'cup',
#   'bottle',
#   'cup',
#   'cup',
#   'cup',
#   'bottle',
#   'cup'],
#  'dining_table_refrigerator/COCO_train2014_000000449904.jpg': ['person',
#   'dining table',
#   'cup',
#   'refrigerator',
#   'chair',
#   'bottle',
#   'bottle',
#   'chair',
#   'bottle',
#   'bottle',
#   'chair',
#   'chair',
#   'bottle',
#   'bottle',
#   'bottle',
#   'chair',
#   'potted plant',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'cake',
#   'dining table',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'dining table',
#   'chair',
#   'bottle'],
#  'dining_table_refrigerator/COCO_train2014_000000177775.jpg': ['refrigerator',
#   'person',
#   'bottle',
#   'chair',
#   'bottle',
#   'bottle',
#   'oven',
#   'sink'],
#  'dining_table_refrigerator/COCO_train2014_000000330112.jpg': ['refrigerator',
#   'microwave',
#   'chair',
#   'bed',
#   'oven',
#   'oven',
#   'bowl',
#   'chair',
#   'knife',
#   'tv',
#   'bench',
#   'chair',
#   'refrigerator'],
#  'dining_table_refrigerator/COCO_train2014_000000317237.jpg': ['person',
#   'refrigerator',
#   'bowl',
#   'chair',
#   'dining table'],
#  'dining_table_refrigerator/COCO_train2014_000000043256.jpg': ['potted plant',
#   'chair',
#   'bottle',
#   'chair',
#   'bottle',
#   'bottle',
#   'refrigerator',
#   'chair',
#   'refrigerator',
#   'bottle',
#   'dining table',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle'],
#  'dining_table_laptop/COCO_train2014_000000093469.jpg': ['laptop',
#   'dining table',
#   'keyboard',
#   'person',
#   'vase'],
#  'dining_table_laptop/COCO_train2014_000000082894.jpg': ['laptop',
#   'bowl',
#   'car',
#   'dining table',
#   'fork',
#   'potted plant',
#   'motorcycle',
#   'spoon',
#   'motorcycle',
#   'cup',
#   'bowl',
#   'potted plant',
#   'keyboard',
#   'chair',
#   'person',
#   'fork',
#   'spoon',
#   'bench',
#   'chair',
#   'potted plant'],
#  'dining_table_laptop/COCO_train2014_000000014238.jpg': ['person',
#   'laptop',
#   'chair',
#   'laptop',
#   'laptop',
#   'person',
#   'dining table',
#   'dining table',
#   'laptop',
#   'person',
#   'dining table',
#   'person'],
#  'dining_table_laptop/COCO_train2014_000000522129.jpg': ['laptop',
#   'laptop',
#   'fork',
#   'fork',
#   'broccoli',
#   'cell phone',
#   'knife',
#   'bottle',
#   'bowl',
#   'knife',
#   'dining table',
#   'broccoli',
#   'book',
#   'book',
#   'keyboard',
#   'book',
#   'bowl',
#   'book',
#   'book',
#   'book',
#   'book'],
#  'dining_table_laptop/COCO_train2014_000000341060.jpg': ['laptop',
#   'chair',
#   'cup',
#   'chair',
#   'cell phone',
#   'chair',
#   'keyboard',
#   'dining table',
#   'chair',
#   'bottle'],
#  'dining_table_laptop/COCO_train2014_000000483794.jpg': ['laptop',
#   'cup',
#   'teddy bear',
#   'dining table',
#   'dining table',
#   'dining table'],
#  'dining_table_laptop/COCO_train2014_000000259745.jpg': ['laptop',
#   'vase',
#   'person',
#   'dining table',
#   'potted plant',
#   'tv'],
#  'bowl_dining_table/COCO_train2014_000000310714.jpg': ['cup',
#   'spoon',
#   'spoon',
#   'bowl',
#   'dining table',
#   'bowl',
#   'broccoli',
#   'broccoli',
#   'bowl'],
#  'bowl_dining_table/COCO_train2014_000000356290.jpg': ['fork',
#   'broccoli',
#   'dining table',
#   'cup',
#   'bowl',
#   'person',
#   'bowl',
#   'cup',
#   'spoon',
#   'knife',
#   'spoon',
#   'bowl'],
#  'bowl_dining_table/COCO_train2014_000000244425.jpg': ['cup',
#   'cup',
#   'dining table',
#   'bowl',
#   'bowl',
#   'mouse',
#   'cup'],
#  'bowl_dining_table/COCO_train2014_000000260248.jpg': ['bowl',
#   'bowl',
#   'bowl',
#   'bowl',
#   'dining table',
#   'spoon',
#   'knife',
#   'spoon',
#   'cake'],
#  'person_truck/COCO_train2014_000000292358.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'truck',
#   'handbag',
#   'truck',
#   'bus',
#   'person',
#   'handbag',
#   'handbag',
#   'handbag'],
#  'person_truck/COCO_train2014_000000032674.jpg': ['person',
#   'car',
#   'truck',
#   'truck'],
#  'person_truck/COCO_train2014_000000087219.jpg': ['person',
#   'person',
#   'umbrella',
#   'person',
#   'handbag',
#   'person',
#   'person',
#   'handbag',
#   'person'],
#  'person_truck/COCO_train2014_000000265781.jpg': ['person',
#   'person',
#   'car',
#   'person',
#   'car',
#   'bench',
#   'bicycle',
#   'truck',
#   'sink',
#   'truck'],
#  'bus_truck/COCO_train2014_000000483534.jpg': ['bus',
#   'car',
#   'traffic light',
#   'car',
#   'truck',
#   'bus',
#   'bus',
#   'truck',
#   'truck'],
#  'bus_truck/COCO_train2014_000000327330.jpg': ['bus',
#   'truck',
#   'person',
#   'person'],
#  'bus_truck/COCO_train2014_000000308175.jpg': ['person',
#   'motorcycle',
#   'person',
#   'car',
#   'car',
#   'car',
#   'truck',
#   'car',
#   'truck'],
#  'person_tv/COCO_train2014_000000210471.jpg': ['person',
#   'tv',
#   'laptop',
#   'mouse',
#   'chair',
#   'dog',
#   'toothbrush',
#   'keyboard',
#   'tv',
#   'toothbrush',
#   'cell phone',
#   'book'],
#  'person_tv/COCO_train2014_000000493114.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'chair',
#   'cake',
#   'tv',
#   'person',
#   'handbag'],
#  'person_tv/COCO_train2014_000000475957.jpg': ['person', 'donut'],
#  'person_tv/COCO_train2014_000000035771.jpg': ['person',
#   'chair',
#   'tv',
#   'chair',
#   'remote',
#   'remote',
#   'laptop'],
#  'person_tv/COCO_train2014_000000263385.jpg': ['person',
#   'tv',
#   'person',
#   'person',
#   'person'],
#  'person_tv/COCO_train2014_000000420617.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'keyboard',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'tv',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'person_tv/COCO_train2014_000000403999.jpg': ['person',
#   'person',
#   'tv',
#   'cup',
#   'bottle',
#   'wine glass',
#   'couch',
#   'remote',
#   'person',
#   'potted plant',
#   'person',
#   'remote'],
#  'person_cake/COCO_train2014_000000478537.jpg': ['person',
#   'chair',
#   'cup',
#   'person',
#   'person',
#   'bowl',
#   'dining table',
#   'fork',
#   'cake',
#   'cake',
#   'fork',
#   'person',
#   'fork',
#   'fork',
#   'umbrella',
#   'fork',
#   'fork',
#   'fork',
#   'fork',
#   'bowl',
#   'dining table',
#   'fork',
#   'fork',
#   'fork'],
#  'person_cake/COCO_train2014_000000488127.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'backpack',
#   'bowl'],
#  'person_cake/COCO_train2014_000000084211.jpg': ['person',
#   'person',
#   'person',
#   'cake',
#   'person',
#   'person',
#   'dining table',
#   'tv'],
#  'bus_truck/COCO_train2014_000000274196.jpg': ['truck', 'bus', 'boat'],
#  'bus_truck/COCO_train2014_000000349204.jpg': ['person',
#   'bus',
#   'truck',
#   'person',
#   'person',
#   'handbag',
#   'person'],
#  'bus_truck/COCO_train2014_000000400091.jpg': ['car', 'truck'],
#  'bus_truck/COCO_train2014_000000557394.jpg': ['person',
#   'bicycle',
#   'truck',
#   'person',
#   'person',
#   'person',
#   'truck',
#   'bicycle',
#   'bus'],
#  'person_dog/COCO_train2014_000000171262.jpg': ['person',
#   'person',
#   'car',
#   'car',
#   'car',
#   'dog',
#   'car',
#   'dog',
#   'car',
#   'bench',
#   'bicycle',
#   'bench'],
#  'person_dog/COCO_train2014_000000421393.jpg': ['tv',
#   'dog',
#   'remote',
#   'person',
#   'chair',
#   'cup',
#   'book',
#   'book'],
#  'person_dog/COCO_train2014_000000324156.jpg': ['person',
#   'dog',
#   'dining table',
#   'dining table',
#   'cake'],
#  'person_dog/COCO_train2014_000000145499.jpg': ['bottle', 'person', 'person'],
#  'person_dog/COCO_train2014_000000515186.jpg': ['person',
#   'person',
#   'car',
#   'dog',
#   'potted plant'],
#  'person_dog/COCO_train2014_000000344597.jpg': ['laptop',
#   'person',
#   'remote',
#   'dog',
#   'remote'],
#  'person_dog/COCO_train2014_000000402297.jpg': ['dog',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'person_oven/COCO_train2014_000000305709.jpg': ['person', 'oven'],
#  'person_refrigerator/COCO_train2014_000000217700.jpg': ['person',
#   'person',
#   'bowl',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle'],
#  'person_refrigerator/COCO_train2014_000000107157.jpg': ['person',
#   'person',
#   'bottle',
#   'oven',
#   'bottle',
#   'refrigerator',
#   'bowl',
#   'bottle',
#   'bottle',
#   'refrigerator',
#   'bottle',
#   'bowl',
#   'tv',
#   'dining table'],
#  'person_refrigerator/COCO_train2014_000000204987.jpg': ['person',
#   'bottle',
#   'microwave',
#   'bottle'],
#  'person_refrigerator/COCO_train2014_000000254658.jpg': ['person',
#   'cell phone',
#   'refrigerator',
#   'person',
#   'clock',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bowl',
#   'potted plant',
#   'bowl',
#   'bottle'],
#  'person_refrigerator/COCO_train2014_000000449904.jpg': ['person',
#   'dining table',
#   'cup',
#   'refrigerator',
#   'chair',
#   'bottle',
#   'bottle',
#   'chair',
#   'bottle',
#   'bottle',
#   'chair',
#   'chair',
#   'bottle',
#   'bottle',
#   'bottle',
#   'chair',
#   'potted plant',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'cake',
#   'dining table',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'bottle',
#   'dining table',
#   'chair',
#   'bottle'],
#  'person_bed/COCO_train2014_000000560909.jpg': ['dog',
#   'dog',
#   'person',
#   'suitcase',
#   'bed'],
#  'person_bed/COCO_train2014_000000314846.jpg': ['person',
#   'person',
#   'bed',
#   'remote',
#   'remote',
#   'bed',
#   'remote'],
#  'person_bed/COCO_train2014_000000112029.jpg': ['person',
#   'teddy bear',
#   'bed',
#   'bed',
#   'person'],
#  'person_bed/COCO_train2014_000000029642.jpg': ['laptop',
#   'book',
#   'bed',
#   'dog',
#   'book'],
#  'person_bed/COCO_train2014_000000384160.jpg': ['person',
#   'bed',
#   'teddy bear',
#   'person',
#   'person',
#   'bed',
#   'person',
#   'teddy bear'],
#  'person_bed/COCO_train2014_000000575631.jpg': ['teddy bear',
#   'person',
#   'bed',
#   'bottle'],
#  'person_bed/COCO_train2014_000000348269.jpg': ['mouse',
#   'bottle',
#   'person',
#   'laptop',
#   'bed',
#   'bottle',
#   'dog',
#   'person',
#   'bed',
#   'book'],
#  'person_umbrella/COCO_train2014_000000354843.jpg': ['umbrella',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person'],
#  'person_umbrella/COCO_train2014_000000122731.jpg': ['person',
#   'umbrella',
#   'umbrella',
#   'person'],
#  'person_umbrella/COCO_train2014_000000164634.jpg': ['person',
#   'umbrella',
#   'car'],
#  'person_umbrella/COCO_train2014_000000438896.jpg': ['person', 'person'],
#  'person_umbrella/COCO_train2014_000000210266.jpg': ['person',
#   'umbrella',
#   'tie',
#   'umbrella',
#   'umbrella',
#   'umbrella',
#   'apple'],
#  'person_umbrella/COCO_train2014_000000209787.jpg': ['person',
#   'person',
#   'tie',
#   'umbrella',
#   'kite'],
#  'person_umbrella/COCO_train2014_000000568064.jpg': ['person',
#   'person',
#   'umbrella',
#   'umbrella',
#   'umbrella',
#   'umbrella',
#   'umbrella',
#   'person',
#   'person',
#   'umbrella',
#   'person',
#   'person'],
#  'person_umbrella/COCO_train2014_000000159965.jpg': ['person',
#   'umbrella',
#   'person',
#   'person',
#   'tie',
#   'car',
#   'person',
#   'umbrella'],
#  'person_oven/COCO_train2014_000000550438.jpg': ['person', 'oven'],
#  'person_oven/COCO_train2014_000000118694.jpg': ['person',
#   'bowl',
#   'bottle',
#   'bottle',
#   'bowl',
#   'bottle',
#   'oven',
#   'bottle',
#   'bottle',
#   'bowl',
#   'spoon'],
#  'person_oven/COCO_train2014_000000560784.jpg': ['person',
#   'oven',
#   'person',
#   'person',
#   'bowl',
#   'knife',
#   'oven',
#   'spoon',
#   'cup',
#   'knife',
#   'bowl',
#   'bowl',
#   'microwave',
#   'person'],
#  'person_oven/COCO_train2014_000000203730.jpg': ['person',
#   'oven',
#   'oven',
#   'oven',
#   'oven',
#   'oven'],
#  'person_oven/COCO_train2014_000000439463.jpg': ['person',
#   'sink',
#   'bowl',
#   'spoon',
#   'bowl',
#   'oven'],
#  'cake_dining_table/COCO_train2014_000000336593.jpg': ['cup',
#   'cake',
#   'dining table'],
#  'cake_dining_table/COCO_train2014_000000545573.jpg': ['person', 'cake'],
#  'cake_dining_table/COCO_train2014_000000134238.jpg': ['banana',
#   'bowl',
#   'cake',
#   'bowl',
#   'dining table'],
#  'cake_dining_table/COCO_train2014_000000235744.jpg': ['cup',
#   'cake',
#   'cup',
#   'dining table',
#   'bottle'],
#  'person_cake/COCO_train2014_000000055912.jpg': ['person',
#   'cake',
#   'person',
#   'dining table'],
#  'person_cake/COCO_train2014_000000052928.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'cake',
#   'cake',
#   'knife',
#   'knife',
#   'umbrella',
#   'dining table',
#   'knife',
#   'dining table',
#   'dining table',
#   'bowl'],
#  'person_cake/COCO_train2014_000000481931.jpg': ['person',
#   'person',
#   'cake',
#   'person',
#   'person',
#   'person',
#   'knife',
#   'dining table',
#   'knife'],
#  'person_cake/COCO_train2014_000000447941.jpg': ['person',
#   'person',
#   'person',
#   'person',
#   'cake',
#   'tie',
#   'person',
#   'person',
#   'person',
#   'person',
#   'tie',
#   'person',
#   'person',
#   'tie',
#   'person',
#   'chair',
#   'cake',
#   'tie',
#   'person',
#   'tie'],
#  'person_umbrella/COCO_train2014_000000205931.jpg': ['person',
#   'umbrella',
#   'umbrella',
#   'umbrella'],
#  'person_umbrella/COCO_train2014_000000489469.jpg': ['umbrella',
#   'person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'kite',
#   'handbag',
#   'person',
#   'person',
#   'person',
#   'person',
#   'umbrella'],
#  'person_umbrella/COCO_train2014_000000546408.jpg': ['person',
#   'umbrella',
#   'airplane',
#   'surfboard',
#   'handbag',
#   'truck'],
#  'person_umbrella/COCO_train2014_000000036282.jpg': ['person', 'umbrella'],
#  'person_elephant/COCO_train2014_000000013763.jpg': ['elephant',
#   'person',
#   'elephant'],
#  'person_elephant/COCO_train2014_000000296747.jpg': ['person',
#   'elephant',
#   'person',
#   'person'],
#  'person_elephant/COCO_train2014_000000041649.jpg': ['elephant',
#   'person',
#   'backpack'],
#  'person_elephant/COCO_train2014_000000576598.jpg': ['person',
#   'elephant',
#   'elephant',
#   'person',
#   'person',
#   'handbag',
#   'backpack']}
